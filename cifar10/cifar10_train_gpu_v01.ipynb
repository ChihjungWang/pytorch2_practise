# %%
# 準備數據集
import torchvision
from torch import nn, optim
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

from models.model_Tudui import *
import time

train_data = torchvision.datasets.CIFAR10(root='./dataset/CIFAR10', train=True, transform=torchvision.transforms.ToTensor(), download=True)
test_data = torchvision.datasets.CIFAR10(root='./dataset/CIFAR10', train=False, transform=torchvision.transforms.ToTensor(), download=True)


train_data_size = len(train_data)
test_data_size = len(test_data)

print(f'訓練數據集的長度為: {train_data_size}')
print(f'測試數據集的長度為: {test_data_size}')

# 利用 dataloader 加載數據集
train_dataloader = DataLoader(train_data, batch_size=64)
test_dataloader = DataLoader(test_data, batch_size=64)

# 建立網路模型
tudui = Tudui()
if torch.cuda.is_available():
    tudui = tudui.cuda()

# 損失函數
loss_fn = nn.CrossEntropyLoss()
if torch.cuda.is_available():
    loss_fn = loss_fn.cuda()

# 優化器
# learning_rate = 0.01
# 1e-2
learning_rate = 1e-2
optimizer = torch.optim.SGD(tudui.parameters(), lr=learning_rate)




# 設至訓練網路的一些參數
# 紀錄訓練的次數
total_train_step = 0
# 紀錄測試的次數
total_test_step = 0
# 訓練的輪數
epoch = 20


# 添加 tensorboard
writer = SummaryWriter("logs_train")

start_time = time.time()
for i in range(epoch):
    print(f'---------第 {i+1} 輪訓練開始---------')
    # 訓練步驟開始
    tudui.train()
    for data in train_dataloader:
        imgs, targets = data
        if torch.cuda.is_available():
            imgs = imgs.cuda()
            targets = targets.cuda()
        outputs = tudui(imgs)
        loss = loss_fn(outputs, targets)

        # 優化器優化模型
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # loss.item() 轉成 python 物件
        total_train_step = total_train_step + 1
        if total_train_step % 100 == 0:
            print(f'訓練次數: {total_train_step}, Loss: {round(loss.item(),4)}')
            writer.add_scalar('train_loss', loss.item(), total_train_step)
    end_time = time.time()
    print(f'訓練花費時間:{round(end_time-start_time, 4)}秒') 
    # 測試步驟開始
    tudui.eval()
    total_test_loss = 0
    total_accuracy = 0
    with torch.no_grad():
        for data in test_dataloader:
            imgs, targets = data
            if torch.cuda.is_available():
                imgs = imgs.cuda()
                targets = targets.cuda()
            outputs = tudui(imgs)
            loss = loss_fn(outputs, targets)
            total_test_loss = total_test_loss + loss.item()
            accuracy = (outputs.argmax(1) == targets).sum()
            total_accuracy = total_accuracy + accuracy
    accuracy_rate = total_accuracy.item()/test_data_size
    print(f'整體測試集上的loss: {total_test_loss}')
    print(f'整體測試集上的正確率: {accuracy_rate}')
    writer.add_scalar('test_loss', total_test_loss, total_test_step)
    writer.add_scalar('test_accuracy', accuracy_rate, total_test_step)
    total_test_step = total_test_step + 1

    torch.save(tudui, f"checkpoints/tudui_{i}.pth")
    # torch.save(tudui.state_dict(), f"checkpoints/tudui_{i}.pth")
    print('模型已保存')


writer.close()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 訓練數據集的長度為: 50000
# 測試數據集的長度為: 10000
# ---------第 1 輪訓練開始---------
# 訓練次數: 100, Loss: 2.2888
# 訓練次數: 200, Loss: 2.2856
# 訓練次數: 300, Loss: 2.2597
# 訓練次數: 400, Loss: 2.18
# 訓練次數: 500, Loss: 2.0622
# 訓練次數: 600, Loss: 1.9869
# 訓練次數: 700, Loss: 2.0323
# 訓練花費時間:7.0595
# 整體測試集上的loss: 319.4511944055557
# 整體測試集上的正確率: 0.2761
# 模型已保存
# ---------第 2 輪訓練開始---------
# 訓練次數: 800, Loss: 1.8688
# 訓練次數: 900, Loss: 1.8535
# 訓練次數: 1000, Loss: 1.9047
# 訓練次數: 1100, Loss: 1.9666
# 訓練次數: 1200, Loss: 1.6923
# 訓練次數: 1300, Loss: 1.6485
# 訓練次數: 1400, Loss: 1.73
# 訓練次數: 1500, Loss: 1.824
# 訓練花費時間:14.9578
# 整體測試集上的loss: 305.16554152965546
# 整體測試集上的正確率: 0.3138
# 模型已保存
# ---------第 3 輪訓練開始---------
# 訓練次數: 1600, Loss: 1.7588
# 訓練次數: 1700, Loss: 1.6347
# 訓練次數: 1800, Loss: 1.9415
# 訓練次數: 1900, Loss: 1.6931
# 訓練次數: 2000, Loss: 1.8994
# 訓練次數: 2100, Loss: 1.516
# 訓練次數: 2200, Loss: 1.4472
# 訓練次數: 2300, Loss: 1.7994
# 訓練花費時間:22.914
# 整體測試集上的loss: 267.35631120204926
# 整體測試集上的正確率: 0.3819
# 模型已保存
# ---------第 4 輪訓練開始---------
# 訓練次數: 2400, Loss: 1.7393
# 訓練次數: 2500, Loss: 1.3315
# 訓練次數: 2600, Loss: 1.5646
# 訓練次數: 2700, Loss: 1.6347
# 訓練次數: 2800, Loss: 1.4408
# 訓練次數: 2900, Loss: 1.5742
# 訓練次數: 3000, Loss: 1.3474
# 訓練次數: 3100, Loss: 1.4875
# 訓練花費時間:30.8207
# 整體測試集上的loss: 266.2551692724228
# 整體測試集上的正確率: 0.3914
# 模型已保存
# ---------第 5 輪訓練開始---------
# 訓練次數: 3200, Loss: 1.3373
# 訓練次數: 3300, Loss: 1.4985
# 訓練次數: 3400, Loss: 1.4384
# 訓練次數: 3500, Loss: 1.5143
# 訓練次數: 3600, Loss: 1.5473
# 訓練次數: 3700, Loss: 1.334
# 訓練次數: 3800, Loss: 1.2566
# 訓練次數: 3900, Loss: 1.479
# 訓練花費時間:39.2642
# 整體測試集上的loss: 250.19370293617249
# 整體測試集上的正確率: 0.4265
# 模型已保存
# ---------第 6 輪訓練開始---------
# 訓練次數: 4000, Loss: 1.3609
# 訓練次數: 4100, Loss: 1.4156
# 訓練次數: 4200, Loss: 1.5189
# 訓練次數: 4300, Loss: 1.1789
# 訓練次數: 4400, Loss: 1.1083
# 訓練次數: 4500, Loss: 1.3414
# 訓練次數: 4600, Loss: 1.3714
# 訓練花費時間:47.9483
# 整體測試集上的loss: 232.8944135904312
# 整體測試集上的正確率: 0.465
# 模型已保存
# ---------第 7 輪訓練開始---------
# 訓練次數: 4700, Loss: 1.3521
# 訓練次數: 4800, Loss: 1.4727
# 訓練次數: 4900, Loss: 1.4012
# 訓練次數: 5000, Loss: 1.3672
# 訓練次數: 5100, Loss: 0.9908
# 訓練次數: 5200, Loss: 1.3031
# 訓練次數: 5300, Loss: 1.1431
# 訓練次數: 5400, Loss: 1.3355
# 訓練花費時間:56.1265
# 整體測試集上的loss: 216.70824468135834
# 整體測試集上的正確率: 0.5004
# 模型已保存
# ---------第 8 輪訓練開始---------
# 訓練次數: 5500, Loss: 1.1818
# 訓練次數: 5600, Loss: 1.1918
# 訓練次數: 5700, Loss: 1.1932
# 訓練次數: 5800, Loss: 1.2088
# 訓練次數: 5900, Loss: 1.3406
# 訓練次數: 6000, Loss: 1.5314
# 訓練次數: 6100, Loss: 1.0062
# 訓練次數: 6200, Loss: 1.053
# 訓練花費時間:64.5326
# 整體測試集上的loss: 204.64976227283478
# 整體測試集上的正確率: 0.5347
# 模型已保存
# ---------第 9 輪訓練開始---------
# 訓練次數: 6300, Loss: 1.4214
# 訓練次數: 6400, Loss: 1.0506
# 訓練次數: 6500, Loss: 1.5363
# 訓練次數: 6600, Loss: 1.0918
# 訓練次數: 6700, Loss: 1.0616
# 訓練次數: 6800, Loss: 1.2197
# 訓練次數: 6900, Loss: 1.1335
# 訓練次數: 7000, Loss: 0.8982
# 訓練花費時間:72.7832
# 整體測試集上的loss: 194.62677532434464
# 整體測試集上的正確率: 0.5595
# 模型已保存
# ---------第 10 輪訓練開始---------
# 訓練次數: 7100, Loss: 1.1834
# 訓練次數: 7200, Loss: 0.9456
# 訓練次數: 7300, Loss: 1.1213
# 訓練次數: 7400, Loss: 0.7779
# 訓練次數: 7500, Loss: 1.2171
# 訓練次數: 7600, Loss: 1.2884
# 訓練次數: 7700, Loss: 0.8549
# 訓練次數: 7800, Loss: 1.2312
# 訓練花費時間:81.1809
# 整體測試集上的loss: 188.09218138456345
# 整體測試集上的正確率: 0.5749
# 模型已保存
# ---------第 11 輪訓練開始---------
# 訓練次數: 7900, Loss: 1.265
# 訓練次數: 8000, Loss: 1.0223
# 訓練次數: 8100, Loss: 0.9471
# 訓練次數: 8200, Loss: 1.2449
# 訓練次數: 8300, Loss: 1.2954
# 訓練次數: 8400, Loss: 1.0845
# 訓練次數: 8500, Loss: 1.2264
# 訓練次數: 8600, Loss: 0.8545
# 訓練花費時間:89.7553
# 整體測試集上的loss: 183.49141240119934
# 整體測試集上的正確率: 0.5851
# 模型已保存
# ---------第 12 輪訓練開始---------
# 訓練次數: 8700, Loss: 1.1491
# 訓練次數: 8800, Loss: 1.3057
# 訓練次數: 8900, Loss: 1.007
# 訓練次數: 9000, Loss: 1.1031
# 訓練次數: 9100, Loss: 1.0255
# 訓練次數: 9200, Loss: 1.0688
# 訓練次數: 9300, Loss: 1.0357
# 訓練花費時間:98.1968
# 整體測試集上的loss: 180.58022648096085
# 整體測試集上的正確率: 0.5954
# 模型已保存
# ---------第 13 輪訓練開始---------
# 訓練次數: 9400, Loss: 0.8144
# 訓練次數: 9500, Loss: 1.3122
# 訓練次數: 9600, Loss: 1.1229
# 訓練次數: 9700, Loss: 1.0134
# 訓練次數: 9800, Loss: 0.9614
# 訓練次數: 9900, Loss: 0.987
# 訓練次數: 10000, Loss: 0.9337
# 訓練次數: 10100, Loss: 0.8736
# 訓練花費時間:107.0011
# 整體測試集上的loss: 177.84720546007156
# 整體測試集上的正確率: 0.6033
# 模型已保存
# ---------第 14 輪訓練開始---------
# 訓練次數: 10200, Loss: 0.7648
# 訓練次數: 10300, Loss: 1.0204
# 訓練次數: 10400, Loss: 1.2014
# 訓練次數: 10500, Loss: 0.7764
# 訓練次數: 10600, Loss: 0.8916
# 訓練次數: 10700, Loss: 0.695
# 訓練次數: 10800, Loss: 0.835
# 訓練次數: 10900, Loss: 0.9392
# 訓練花費時間:115.2311
# 整體測試集上的loss: 174.88643407821655
# 整體測試集上的正確率: 0.6111
# 模型已保存
# ---------第 15 輪訓練開始---------
# 訓練次數: 11000, Loss: 1.1255
# 訓練次數: 11100, Loss: 0.83
# 訓練次數: 11200, Loss: 1.0319
# 訓練次數: 11300, Loss: 1.0602
# 訓練次數: 11400, Loss: 0.7547
# 訓練次數: 11500, Loss: 1.1055
# 訓練次數: 11600, Loss: 0.9376
# 訓練次數: 11700, Loss: 0.8556
# 訓練花費時間:123.7339
# 整體測試集上的loss: 172.0043168067932
# 整體測試集上的正確率: 0.6201
# 模型已保存
# ---------第 16 輪訓練開始---------
# 訓練次數: 11800, Loss: 0.8732
# 訓練次數: 11900, Loss: 0.942
# 訓練次數: 12000, Loss: 0.7314
# 訓練次數: 12100, Loss: 1.0833
# 訓練次數: 12200, Loss: 1.0432
# 訓練次數: 12300, Loss: 0.7815
# 訓練次數: 12400, Loss: 0.9324
# 訓練次數: 12500, Loss: 0.7152
# 訓練花費時間:131.9586
# 整體測試集上的loss: 169.45555186271667
# 整體測試集上的正確率: 0.6263
# 模型已保存
# ---------第 17 輪訓練開始---------
# 訓練次數: 12600, Loss: 0.693
# 訓練次數: 12700, Loss: 0.8696
# 訓練次數: 12800, Loss: 0.7877
# 訓練次數: 12900, Loss: 1.0424
# 訓練次數: 13000, Loss: 0.962
# 訓練次數: 13100, Loss: 0.6135
# 訓練次數: 13200, Loss: 0.7838
# 訓練花費時間:140.0453
# 整體測試集上的loss: 166.34524405002594
# 整體測試集上的正確率: 0.6357
# 模型已保存
# ---------第 18 輪訓練開始---------
# 訓練次數: 13300, Loss: 0.8641
# 訓練次數: 13400, Loss: 0.7624
# 訓練次數: 13500, Loss: 0.8305
# 訓練次數: 13600, Loss: 1.197
# 訓練次數: 13700, Loss: 0.7361
# 訓練次數: 13800, Loss: 0.9897
# 訓練次數: 13900, Loss: 0.7246
# 訓練次數: 14000, Loss: 0.7155
# 訓練花費時間:148.418
# 整體測試集上的loss: 164.07057094573975
# 整體測試集上的正確率: 0.64
# 模型已保存
# ---------第 19 輪訓練開始---------
# 訓練次數: 14100, Loss: 1.0481
# 訓練次數: 14200, Loss: 0.9024
# 訓練次數: 14300, Loss: 0.877
# 訓練次數: 14400, Loss: 1.0399
# 訓練次數: 14500, Loss: 0.885
# 訓練次數: 14600, Loss: 1.0389
# 訓練次數: 14700, Loss: 0.7835
# 訓練次數: 14800, Loss: 1.106
# 訓練花費時間:156.4345
# 整體測試集上的loss: 162.5101904273033
# 整體測試集上的正確率: 0.6464
# 模型已保存
# ---------第 20 輪訓練開始---------
# 訓練次數: 14900, Loss: 0.6057
# 訓練次數: 15000, Loss: 0.8289
# 訓練次數: 15100, Loss: 0.7005
# 訓練次數: 15200, Loss: 0.9389
# 訓練次數: 15300, Loss: 0.6623
# 訓練次數: 15400, Loss: 0.8367
# 訓練次數: 15500, Loss: 0.9997
# 訓練次數: 15600, Loss: 0.7951
# 訓練花費時間:164.7507
# 整體測試集上的loss: 161.83282321691513
# 整體測試集上的正確率: 0.6479
# 模型已保存
